# %% [markdown]
# # 1. Data checking

# %%
import pandas as pd
import numpy as np

from datetime import datetime as dt
from datetime import timedelta

# %% [markdown]
# ## 1) yellow trip data from 2019 Jan

# %%
y1901 = pd.read_parquet("D:/Working_Place/new_uber/data/yellow_tripdata_2019-01.parquet")
y1901.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
# 5         2  2018-11-28 16:25:49   2018-11-28 16:28:26              5.0
# 6         2  2018-11-28 16:29:37   2018-11-28 16:33:43              5.0
# 7         1  2019-01-01 00:21:28   2019-01-01 00:28:37              1.0
# 8         1  2019-01-01 00:32:01   2019-01-01 00:45:39              1.0
# 9         1  2019-01-01 00:57:32   2019-01-01 01:09:32              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# 1            2.6         1.0                  N           239           246
# 2            0.0         1.0                  N           236           236
# 3            0.0         1.0                  N           193           193
# 4            0.0         2.0                  N           193           193
# 5            0.0         1.0                  N           193           193
# 6            0.0         2.0                  N           193           193
# 7            1.3         1.0                  N           163           229
# 8            3.7         1.0                  N           229             7
# 9            2.1         1.0                  N           141           234
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          7.0    0.5      0.5        1.65          0.00
# 1             1         14.0    0.5      0.5        1.00          0.00
# 2             1          4.5    0.5      0.5        0.00          0.00
# 3             2          3.5    0.5      0.5        0.00          0.00
# 4             2         52.0    0.0      0.5        0.00          0.00
# 5             2          3.5    0.5      0.5        0.00          5.76
# 6             2         52.0    0.0      0.5        0.00          0.00
# 7             1          6.5    0.5      0.5        1.25          0.00
# 8             1         13.5    0.5      0.5        3.70          0.00
# 9             1         10.0    0.5      0.5        1.70          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.3          9.95                   NaN          NaN
# 1                    0.3         16.30                   NaN          NaN
# 2                    0.3          5.80                   NaN          NaN
# 3                    0.3          7.55                   NaN          NaN
# 4                    0.3         55.55                   NaN          NaN
# 5                    0.3         13.31                   NaN          NaN
# 6                    0.3         55.55                   NaN          NaN
# 7                    0.3          9.05                   NaN          NaN
# 8                    0.3         18.50                   NaN          NaN
# 9                    0.3         13.00                   NaN          NaN

# %%
print(y1901.columns)
##let's do it columns by columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %% [markdown]
# ### -1. VendorID

# %%
print(y1901.VendorID.unique())
# Out:
# [1 2 4 5]

# %% [markdown]
# What is 4,5...? But it doesn't matter

# %% [markdown]
# ### -2. pickup & dropoff datetime

# %%
y1901[y1901.tpep_pickup_datetime.dt.hour==1]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 766             2  2019-01-01 01:00:20   2019-01-01 01:16:16              1.0
# 966             2  2019-01-01 01:03:03   2019-01-01 01:07:50              2.0
# 1052            2  2019-01-01 01:00:57   2019-01-01 01:07:52              1.0
# 1057            2  2019-01-01 01:01:04   2019-01-01 01:06:10              1.0
# 1129            2  2019-01-01 01:11:04   2019-01-01 01:29:03              1.0
# ...           ...                  ...                   ...              ...
# 7694758         2  2019-01-30 01:38:52   2019-01-30 01:45:18              NaN
# 7694759         2  2019-01-30 01:11:00   2019-01-30 01:37:00              NaN
# 7694760         2  2019-01-30 01:41:28   2019-01-30 02:07:20              NaN
# 7695737         2  2019-01-31 01:04:00   2019-01-31 01:30:00              NaN
# 7695738         2  2019-01-31 01:44:39   2019-01-31 02:09:59              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 766               4.06         1.0                  N           141
# 966               1.15         1.0                  N           263
# 1052              1.25         1.0                  N           244
# 1057              1.43         1.0                  N           238
# 1129              3.66         1.0                  N           236
# ...                ...         ...                ...           ...
# 7694758           1.53         NaN               None            65
# 7694759          14.82         NaN               None             4
# 7694760          10.26         NaN               None           114
# 7695737          15.00         NaN               None             4
# 7695738          10.95         NaN               None            65
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 766               166             2        14.50   0.50      0.5        0.00
# 966               141             2         5.50   0.50      0.5        0.00
# 1052              243             2         7.00   0.50      0.5        0.00
# 1057              166             1         6.50   0.50      0.5        2.34
# 1129              152             1        15.00   0.50      0.5        4.89
# ...               ...           ...          ...    ...      ...         ...
# 7694758            66             0        43.45   2.75      0.0        0.00
# 7694759           174             0        59.15   2.75      0.5        0.00
# 7694760            42             0        43.45   2.75      0.0        0.00
# 7695737           174             0        59.15   2.75      0.5        0.00
# 7695738            75             0        43.45   2.75      0.0        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 766               0.0                    0.3         15.80
# 966               0.0                    0.3          6.80
# 1052              0.0                    0.3          8.30
# 1057              0.0                    0.3         10.14
# 1129              0.0                    0.3         21.19
# ...               ...                    ...           ...
# 7694758           0.0                    0.3         46.50
# 7694759           0.0                    0.3         62.70
# 7694760           0.0                    0.3         46.50
# 7695737           0.0                    0.3         62.70
# 7695738           0.0                    0.3         46.50
#
#          congestion_surcharge  airport_fee
# 766                       NaN          NaN
# 966                       NaN          NaN
# 1052                      NaN          NaN
# 1057                      NaN          NaN
# 1129                      NaN          NaN
# ...                       ...          ...
# 7694758                   NaN          NaN
# 7694759                   NaN          NaN
# 7694760                   NaN          NaN
# 7695737                   NaN          NaN
# 7695738                   NaN          NaN
#
# [149254 rows x 19 columns]
